# %% [markdown]
# # [Face Detection with a Sliding Window](https://www.cc.gatech.edu/~hays/compvision/proj5/)
# 1. Extract features for positive examples
# 2. Extract features for random negative examples
# 3. Mine hard negatives
# 4. Train a linear classifier
# 5. Detect faces on the test set

# %% [markdown]
# ## Setup

# %%
# %matplotlib inline
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2
import cv2
import numpy as np
import os.path as osp
import matplotlib.pyplot as plt
from utils import *
import student_code as sc

# %%
data_path = osp.join('..','data')
# Positive training examples. 36x36 head crops
train_path_pos = osp.join(data_path, 'caltech_faces', 'Caltech_CropFaces')
# Mine random or hard negatives from here
non_face_scn_path = osp.join(data_path, 'train_non_face_scenes')
# CMU+MIT test scenes
test_scn_path = osp.join(data_path, 'test_scenes', 'test_jpg')
# Ground truth face locations in the test set
label_filename = osp.join(data_path, 'test_scenes', 'ground_truth_bboxes.txt')

# The faces are 36x36 pixels, which works fine as a template size. You could
# add other fields to this dict if you want to modify HoG default
# parameters such as the number of orientations, but that does not help
# performance in our limited test.
feature_params = {'template_size': 36, 'hog_cell_size': 6}

# Number of negatives to use for training.
# Higher will work strictly better, but you should start with 10000 for debugging
num_negative_examples = 13000

# %% [markdown]
# ## Section 1: Load positive training crops and random negative examples

# %%
#sc.generateFlippedPositives(train_path_pos)
features_pos = sc.get_positive_features(train_path_pos, feature_params)
# Out:
# positive feature shape(6713, 1116)

# %%
features_neg = sc.get_random_negative_features(non_face_scn_path, feature_params,
                                               num_negative_examples)
# Out:
# negative feature shape(6796, 1116)
# RunTime Took: 27.281185999999998 seconds.

# %% [markdown]
# ## Section 2: Train Classifier
# Use [scikit-learn LinearSVC](http://scikit-learn.org/stable/modules/generated/sklearn.svm.LinearSVC.html#sklearn.svm.LinearSVC) to on your training features to learn a linear classifier. The regularization constant C is an important parameter, try many values. Small values seem to work better (e.g. 1e-4), but you can try other values.

# %%
svm = sc.train_classifier(features_pos, features_neg, 1e-1)
# Out:
# Total Positive Size (6713, 1116)
# Total Negative Size (6796, 1116)
# Total Train Size (13509, 1116)

# %% [markdown]
# ## Section 3: Examine Learned Classifier
# You don't need to modify anything in this section. The section first
# evaluates _training_ error, which isn't ultimately what we care about,
# but it's a good sanity check. Your training error should be very low.

# %%
confidences = svm.decision_function(np.vstack((features_pos, features_neg)))
label_vector = np.hstack((np.ones(len(features_pos)), -np.ones(len(features_neg))))
[tp_rate, fp_rate, tn_rate, fn_rate] = report_accuracy(confidences, label_vector)
# Out:
# Accuracy = 99.830%
# True Positive rate = 99.747%
# False Positive rate = 0.088%
# True Negative rate = 99.912%
# False Negative rate = 0.253%

# %% [markdown]
# Visualize how well separated the positive and negative examples are at
# training time. Sometimes this can idenfity odd biases in your training
# data, especially if you're trying hard negative mining. This
# visualization won't be very meaningful with the placeholder starter code.

# %%
face_confs = confidences[label_vector > 0]
non_face_confs = confidences[label_vector < 0]
plt.figure()
plt.hist(np.sort(face_confs), 100, facecolor='g', histtype='step', density=1,label='faces')
plt.hist(np.sort(non_face_confs), 100, facecolor='r', histtype='step',density=1, label='non faces')
#plt.plot([0, len(non_face_confs)], [0, 0], 'b', label='decision boundary')
plt.xlabel('predicted score')
plt.ylabel('Percentage of images')
plt.legend()

# %% [markdown]
# Visualize the HOG feature template to examine if the detector has learned a meaningful representation for the object (faces in this case).  This would be a good thing to include in your writeup.

# %%
visualize_hog(svm, feature_params)

# %% [markdown]
# ## Section 4: Mine Hard Negatives
# You can get very good performance by using random negatives, so hard negative mining may not show great improvement for face detection. Hard negative mining would probably be more important if you had a strict budget of negative training examples or a
# more expressive, non-linear classifier that can benefit from more training data.

# %%
hard_negs = sc.mine_hard_negs(non_face_scn_path, svm, feature_params)
features_neg_2 = np.vstack((features_neg, hard_negs))

# %% [markdown]
# Then you can train the classifier again with the new features_neg. You can also check the difference of the performance.

# %%
svm_2 = sc.train_classifier(features_pos, features_neg_2, 1e-1)

# %% [markdown]
# ## Section 5: Run Detector on Test Set
# Make sure the outputs of sc.run_detector() are properly structured! They will be interpreted in Section 6 to evaluate and visualize your
# results. See sc.run_detector() documentation for more details.
#
# sc.run_detector() will have (at least) two parameters which can heavily
# influence performance - how much to rescale each step of your multiscale
# detector, and the threshold for a detection. If your recall rate is low
# and your detector still has high precision at its highest recall point,
# you can improve your average precision by reducing the threshold for a
# positive detection.

# %%
bboxes, confidences, image_ids = sc.run_detector(test_scn_path, svm, feature_params)
# Out:
# ../data/test_scenes/test_jpg/Argentina.jpg
# ../data/test_scenes/test_jpg/Arsenal.jpg
# ../data/test_scenes/test_jpg/Brazil.jpg
# ../data/test_scenes/test_jpg/Colombia.jpg
# ../data/test_scenes/test_jpg/Ecuador.jpg
# ../data/test_scenes/test_jpg/England.jpg
# ../data/test_scenes/test_jpg/Germany.jpg
# ../data/test_scenes/test_jpg/J-L_Picard.Baldy.jpg
# ../data/test_scenes/test_jpg/USA.jpg
# ../data/test_scenes/test_jpg/addams-family.jpg
# ../data/test_scenes/test_jpg/aeon1a.jpg
# ../data/test_scenes/test_jpg/aerosmith-double.jpg
# ../data/test_scenes/test_jpg/albert.jpg
# ../data/test_scenes/test_jpg/audrey1.jpg
# ../data/test_scenes/test_jpg/audrey2.jpg
# ../data/test_scenes/test_jpg/audrybt1.jpg
# ../data/test_scenes/test_jpg/baseball.jpg
# ../data/test_scenes/test_jpg/bksomels.jpg
# ../data/test_scenes/test_jpg/blues-double.jpg
# ../data/test_scenes/test_jpg/board.jpg
# ../data/test_scenes/test_jpg/boat.jpg
# ../data/test_scenes/test_jpg/book.jpg
# ../data/test_scenes/test_jpg/brian.jpg
# ../data/test_scenes/test_jpg/bttf206.jpg
# ../data/test_scenes/test_jpg/bttf301.jpg
# ../data/test_scenes/test_jpg/bwolen.jpg
# ../data/test_scenes/test_jpg/cards-perp-sml.jpg
# ../data/test_scenes/test_jpg/cfb.jpg
# ../data/test_scenes/test_jpg/churchill-downs.jpg
# ../data/test_scenes/test_jpg/clapton.jpg
# ../data/test_scenes/test_jpg/class57.jpg
# ../data/test_scenes/test_jpg/cluttered-tahoe.jpg
# ../data/test_scenes/test_jpg/cnn1085.jpg
# ../data/test_scenes/test_jpg/cnn1160.jpg
# ../data/test_scenes/test_jpg/cnn1260.jpg
# ../data/test_scenes/test_jpg/cnn1630.jpg
# ../data/test_scenes/test_jpg/cnn1714.jpg
# ../data/test_scenes/test_jpg/cnn2020.jpg
# ../data/test_scenes/test_jpg/cnn2221.jpg
# ../data/test_scenes/test_jpg/cnn2600.jpg
# ../data/test_scenes/test_jpg/cpd.jpg
# ../data/test_scenes/test_jpg/crimson.jpg
# ../data/test_scenes/test_jpg/divinci-man1.jpg
# ../data/test_scenes/test_jpg/ds9.jpg
# ../data/test_scenes/test_jpg/er.jpg
# ../data/test_scenes/test_jpg/eugene.jpg
# ../data/test_scenes/test_jpg/ew-courtney-david.jpg
# ../data/test_scenes/test_jpg/ew-friends.jpg
# ../data/test_scenes/test_jpg/fleetwood-mac.jpg
# ../data/test_scenes/test_jpg/frisbee.jpg
# ../data/test_scenes/test_jpg/giant-panda.jpg
# ../data/test_scenes/test_jpg/gigi.jpg
# ../data/test_scenes/test_jpg/gpripe.jpg
# ../data/test_scenes/test_jpg/harvard.jpg
# ../data/test_scenes/test_jpg/hendrix1-bigger.jpg
# ../data/test_scenes/test_jpg/hendrix2.jpg
# ../data/test_scenes/test_jpg/henry.jpg
# ../data/test_scenes/test_jpg/herbie-hancock.jpg
# ../data/test_scenes/test_jpg/jackson.jpg
# ../data/test_scenes/test_jpg/john.coltrane.jpg
# ../data/test_scenes/test_jpg/judybats.jpg
# ../data/test_scenes/test_jpg/kaari-stef.jpg
# ../data/test_scenes/test_jpg/kaari1.jpg
# ../data/test_scenes/test_jpg/kaari2.jpg
# ../data/test_scenes/test_jpg/karen-and-rob.jpg
# ../data/test_scenes/test_jpg/knex0.jpg
# ../data/test_scenes/test_jpg/knex20.jpg
# ../data/test_scenes/test_jpg/knex37.jpg
# ../data/test_scenes/test_jpg/knex42.jpg
# ../data/test_scenes/test_jpg/kymberly.jpg
# ../data/test_scenes/test_jpg/lacrosse.jpg
# ../data/test_scenes/test_jpg/larroquette.jpg
# ../data/test_scenes/test_jpg/lawoman.jpg
# ../data/test_scenes/test_jpg/life-cover.jpg
# ../data/test_scenes/test_jpg/life-dreams.jpg
# ../data/test_scenes/test_jpg/life2100.jpg
# ../data/test_scenes/test_jpg/life7422.jpg
# ../data/test_scenes/test_jpg/madaboutyou.jpg
# ../data/test_scenes/test_jpg/married.jpg
# ../data/test_scenes/test_jpg/me.jpg
# ../data/test_scenes/test_jpg/mickymouse-self-p.jpg
# ../data/test_scenes/test_jpg/mom-baby.jpg
# ../data/test_scenes/test_jpg/mona-lisa.jpg
# ../data/test_scenes/test_jpg/music-groups-double.jpg
# ../data/test_scenes/test_jpg/natalie1.jpg
# ../data/test_scenes/test_jpg/nens.jpg
# ../data/test_scenes/test_jpg/newsradio.jpg
# ../data/test_scenes/test_jpg/next.jpg
# ../data/test_scenes/test_jpg/oksana1.jpg
# ../data/test_scenes/test_jpg/original1.jpg
# ../data/test_scenes/test_jpg/original2.jpg
# ../data/test_scenes/test_jpg/our-cards.jpg
# ../data/test_scenes/test_jpg/pace-university-double.jpg
# ../data/test_scenes/test_jpg/patio.jpg
# ../data/test_scenes/test_jpg/people.jpg
# ../data/test_scenes/test_jpg/pittsburgh-park.jpg
# ../data/test_scenes/test_jpg/plays.jpg
# ../data/test_scenes/test_jpg/police.jpg
# ../data/test_scenes/test_jpg/puneet.jpg
# ../data/test_scenes/test_jpg/rehg-thanksgiving-1994.jpg
# ../data/test_scenes/test_jpg/sarah4.jpg
# ../data/test_scenes/test_jpg/sarah_live_2.jpg
# ../data/test_scenes/test_jpg/seinfeld.jpg
# ../data/test_scenes/test_jpg/shumeet.jpg
# ../data/test_scenes/test_jpg/soccer.jpg
# ../data/test_scenes/test_jpg/speed.jpg
# ../data/test_scenes/test_jpg/tahoe-and-rich.jpg
# ../data/test_scenes/test_jpg/tammy.jpg
# ../data/test_scenes/test_jpg/tommyrw.jpg
# ../data/test_scenes/test_jpg/tori-crucify.jpg
# ../data/test_scenes/test_jpg/tori-entweekly.jpg
# ../data/test_scenes/test_jpg/tori-live3.jpg
# ../data/test_scenes/test_jpg/torrance.jpg
# ../data/test_scenes/test_jpg/tp-reza-girosi.jpg
# ../data/test_scenes/test_jpg/tp.jpg
# ../data/test_scenes/test_jpg/tree-roots.jpg
# ../data/test_scenes/test_jpg/trek-trio.jpg
# ../data/test_scenes/test_jpg/trekcolr.jpg
# ../data/test_scenes/test_jpg/tress-photo-2.jpg
# ../data/test_scenes/test_jpg/tress-photo.jpg
# ../data/test_scenes/test_jpg/u2-cover.jpg
# ../data/test_scenes/test_jpg/uprooted-tree.jpg
# ../data/test_scenes/test_jpg/voyager.jpg
# ../data/test_scenes/test_jpg/voyager2.jpg
# ../data/test_scenes/test_jpg/wall.jpg
# ../data/test_scenes/test_jpg/waynesworld2.jpg
# ../data/test_scenes/test_jpg/window.jpg
# ../data/test_scenes/test_jpg/wxm.jpg
# ../data/test_scenes/test_jpg/yellow-pages.jpg
# ../data/test_scenes/test_jpg/ysato.jpg
# Done
# RunTime Took: 495.15255099999996 seconds.

# %% [markdown]
# Let's detect again using the classifier trained using hard negative examples. The results will be saved separately.

# %%
bboxes_2, confidences_2, image_ids_2 = sc.run_detector(test_scn_path, svm_2, feature_params)

# %% [markdown]
# ## Section 6: Evaluate and Visualize Detections
# These functions require ground truth annotations, and thus can only be run on the CMU+MIT face test set.
# Don't modify anything in evaluate_detections()!
#
# Performance to aim for:
# - random (stater code): 0.001 AP
# - single scale: ~ 0.3 to 0.4 AP
# - multiscale: ~ 0.75 to 0.9 AP
#
# You need to implement multi-scale detection and achieve at least 0.8 AP to receive the full credit.
#
# First we compare the detection performance between different classifiers quantitatively.

# %%
gt_ids, gt_bboxes, gt_isclaimed, tp, fp, duplicate_detections = evaluate_detections(bboxes, confidences,
                                                                                    image_ids, label_filename)

# %%
gt_ids, gt_bboxes, gt_isclaimed, tp_2, fp_2, duplicate_detections_2 = evaluate_detections(bboxes_2, confidences_2,
                                                                                    image_ids_2, label_filename)

# %% [markdown]
# And then we show the detection results on the test scenes. By default we only show the results from the second classifier. You can also check the first classifier by uncommenting the first line.

# %%
# visualize_detections_by_image(bboxes, confidences, image_ids, tp, fp, test_scn_path, label_filename)
visualize_detections_by_image(bboxes_2, confidences_2, image_ids_2, tp_2, fp_2, test_scn_path, label_filename)

# %% [markdown]
# ## (Optional) Visualize Detections on Extra Scenes
# Uncomment the following codes to test your detector on extra scenes.

# %%
# test_scn_path_extra = osp.join(data_path, 'extra_test_scenes') # Bonus scenes
# bboxes_extra, confidences_extra, image_ids_extra = sc.run_detector(test_scn_path_extra, svm_2, feature_params)

# %%
# visualize_detections_by_image_no_gt(bboxes_extra, confidences_extra, image_ids_extra, test_scn_path_extra)
