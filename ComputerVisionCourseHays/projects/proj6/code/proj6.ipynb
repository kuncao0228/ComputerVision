# %% [markdown]
# # [Deep Learning](https://www.cc.gatech.edu/~hays/compvision/proj6/)

# %% [markdown]
# ## Setup

# %%
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2
import cv2
import numpy as np
import random
import torch.nn as nn
import torch.optim as optim
import os.path as osp
import matplotlib.pyplot as plt
from utils import *
import student_code as sc
from torchvision.models import alexnet

data_path = osp.join('../data', '15SceneData')
num_classes = 15

# If you have a good Nvidia GPU with an appropriate environment, 
# try setting the use_GPU flag to True (the environment provided does
# not support GPUs and we will not provide any support for GPU
# computation in this project). Please note that 
# we will evaluate your implementations only using CPU mode so even if
# you use a GPU, make sure your code runs in the CPU mode with the
# environment we provided. 
use_GPU = False
if use_GPU:
    from utils_gpu import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# To train a network in PyTorch, we need 4 components:
# 1. **Dataset** - an object which can load the data and labels given an index.
# 2. **Model** - an object that contains the network architecture definition.
# 3. **Loss function** - a function that measures how far the network output is from the ground truth label.
# 4. **Optimizer** - an object that optimizes the network parameters to reduce the loss value.

# %% [markdown]
# This project has two main parts. In Part 1, you will train a deep network from scratch. In Part 2, you will "fine-tune" a trained network.

# %% [markdown]
# ## Part 0. Warm up! Training a Deep Network from Scratch

# %%
# Fix random seeds so that results will be reproducible
set_seed(0, use_GPU)

# %% [markdown]
# You do not need to code anything for this part. You will simply run the code we provided, but we want you to report the result you got. This section will also familiarize you with the steps of training a deep network from scratch.

# %%
# Training parameters.
input_size = (64, 64)
RGB = False  
base_lr = 1e-2  # may try a smaller lr if not using batch norm
weight_decay = 5e-4
momentum = 0.9

# %% [markdown]
# We will first create our datasets, by calling the create_datasets function from student_code. This function returns a separate dataset loader for each split of the dataset (training and testing/validation). Each dataloader is used to load the datasets after appling some pre-processing transforms. In Part 1, you will be asked to add a few more pre-processing transforms to the dataloaders by modifying this function.

# %%
# Create the training and testing datasets.
train_dataset, test_dataset = sc.create_datasets(data_path=data_path, input_size=input_size, rgb=RGB)
assert test_dataset.classes == train_dataset.classes
# Out:
# Computing pixel mean and stdev...
# Batch 0 / 30
# Batch 20 / 30
# Done, mean =
# [0.45579668]
# std =
# [0.23624939]
# Computing pixel mean and stdev...
# Batch 0 / 60
# Batch 20 / 60
# Batch 40 / 60
# Done, mean =
# [0.45517009]
# std =
# [0.2350788]

# %% [markdown]
# Now we will create our network model using the SimpleNet class from student_code. The implementation provided in the SimpleNet class gives you a basic network. In Part 1, you will be asked to add a few more layers to this network.

# %%
# Create the network model.
model = sc.SimpleNet(num_classes=num_classes, rgb=False, verbose=False)
if use_GPU:
    model = model.cuda()
print(model)
# Out:
# SimpleNet(
#   (features): Sequential(
#     (0): Conv2d(1, 10, kernel_size=(9, 9), stride=(1, 1), bias=False)
#     (1): MaxPool2d(kernel_size=7, stride=7, padding=0, dilation=1, ceil_mode=False)
#     (2): ReLU()
#   )
#   (classifier): Conv2d(10, 15, kernel_size=(8, 8), stride=(1, 1))
# )

# %% [markdown]
# Next we will create the loss function and the optimizer.

# %%
# Create the loss function.
# see http://pytorch.org/docs/0.3.0/nn.html#loss-functions for a list of available loss functions
loss_function = nn.CrossEntropyLoss()

# %%
# Create the optimizer and a learning rate scheduler
optimizer = optim.SGD(params=model.parameters(), lr=base_lr, weight_decay=weight_decay, momentum=momentum)
# Currently a simple step scheduler.
# See http://pytorch.org/docs/0.3.0/optim.html#how-to-adjust-learning-rate for various LR schedulers
# and how to use them
lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=60, gamma=0.1)

# %% [markdown]
# Finally we are ready to train our network! We will start a local server to see the training progress of our network. Open a new terminal and activate the environment for this project. Then run the following command: **python -m visdom.server**. This will start a local server. The terminal output should give out a link like: "http://localhost:8097". Open this link in your browser. After you run the following block, visit this link again, and you will be able to see graphs showing the progress of your training! If you do not see any graphs, select Part 1 on the top left bar where is says Environment (only select Part 1, do not check main or Part 2).

# %%
# train the network!
params = {'n_epochs': 100, 'batch_size': 50, 'experiment': 'part1'}
trainer = Trainer(train_dataset, test_dataset, model, loss_function, optimizer, lr_scheduler, params)
best_prec1 = trainer.train_val()
print('Best top-1 Accuracy = {:4.3f}'.format(best_prec1))
# Out:
# ---------------------------------------
# Experiment: part1
# do_val: True
# n_epochs: 100
# val_freq: 1
# experiment: part1
# resume_optim: True
# shuffle: True
# batch_size: 50
# checkpoint_file: None
# print_freq: 100
# num_workers: 4
# ---------------------------------------
# part1 Epoch 0 / 100
# train part1: batch 0/29, loss 2.709, top-1 accuracy 8.000, top-5 accuracy 28.000
# train part1: loss 2.708517
# val part1: batch 0/59, loss 2.720, top-1 accuracy 0.000, top-5 accuracy 0.000
# val part1: loss 2.708254
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 1 / 100
# train part1: batch 0/29, loss 2.706, top-1 accuracy 0.000, top-5 accuracy 42.000
# train part1: loss 2.706191
# val part1: batch 0/59, loss 2.649, top-1 accuracy 28.000, top-5 accuracy 100.000
# val part1: loss 2.709384
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 2 / 100
# train part1: batch 0/29, loss 2.703, top-1 accuracy 8.000, top-5 accuracy 34.000
# train part1: loss 2.699870
# val part1: batch 0/59, loss 2.666, top-1 accuracy 0.000, top-5 accuracy 22.000
# val part1: loss 2.692277
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 3 / 100
# train part1: batch 0/29, loss 2.656, top-1 accuracy 24.000, top-5 accuracy 44.000
# train part1: loss 2.671104
# val part1: batch 0/59, loss 2.608, top-1 accuracy 0.000, top-5 accuracy 32.000
# val part1: loss 2.677120
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 4 / 100
# train part1: batch 0/29, loss 2.571, top-1 accuracy 20.000, top-5 accuracy 64.000
# train part1: loss 2.625427
# val part1: batch 0/59, loss 2.588, top-1 accuracy 8.000, top-5 accuracy 42.000
# val part1: loss 2.607365
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 5 / 100
# train part1: batch 0/29, loss 2.434, top-1 accuracy 32.000, top-5 accuracy 56.000
# train part1: loss 2.580128
# val part1: batch 0/59, loss 2.632, top-1 accuracy 0.000, top-5 accuracy 40.000
# val part1: loss 2.608571
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 6 / 100
# train part1: batch 0/29, loss 2.526, top-1 accuracy 26.000, top-5 accuracy 54.000
# train part1: loss 2.515048
# val part1: batch 0/59, loss 2.843, top-1 accuracy 0.000, top-5 accuracy 32.000
# val part1: loss 2.609412
# Checkpoint saved
# part1 Epoch 7 / 100
# train part1: batch 0/29, loss 2.437, top-1 accuracy 24.000, top-5 accuracy 60.000
# train part1: loss 2.465688
# val part1: batch 0/59, loss 2.806, top-1 accuracy 0.000, top-5 accuracy 36.000
# val part1: loss 2.471417
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 8 / 100
# train part1: batch 0/29, loss 2.373, top-1 accuracy 26.000, top-5 accuracy 82.000
# train part1: loss 2.355062
# val part1: batch 0/59, loss 3.035, top-1 accuracy 0.000, top-5 accuracy 8.000
# val part1: loss 2.448728
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 9 / 100
# train part1: batch 0/29, loss 2.285, top-1 accuracy 32.000, top-5 accuracy 64.000
# train part1: loss 2.316558
# val part1: batch 0/59, loss 2.884, top-1 accuracy 0.000, top-5 accuracy 42.000
# val part1: loss 2.432716
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 10 / 100
# train part1: batch 0/29, loss 2.275, top-1 accuracy 32.000, top-5 accuracy 70.000
# train part1: loss 2.211500
# val part1: batch 0/59, loss 3.079, top-1 accuracy 0.000, top-5 accuracy 22.000
# val part1: loss 2.412769
# Checkpoint saved
# part1 Epoch 11 / 100
# train part1: batch 0/29, loss 2.138, top-1 accuracy 32.000, top-5 accuracy 74.000
# train part1: loss 2.177752
# val part1: batch 0/59, loss 2.624, top-1 accuracy 10.000, top-5 accuracy 58.000
# val part1: loss 2.400335
# Checkpoint saved
# part1 Epoch 12 / 100
# train part1: batch 0/29, loss 2.153, top-1 accuracy 26.000, top-5 accuracy 76.000
# train part1: loss 2.103080
# val part1: batch 0/59, loss 2.855, top-1 accuracy 8.000, top-5 accuracy 42.000
# val part1: loss 2.458871
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 13 / 100
# train part1: batch 0/29, loss 1.912, top-1 accuracy 44.000, top-5 accuracy 86.000
# train part1: loss 2.040622
# val part1: batch 0/59, loss 2.123, top-1 accuracy 22.000, top-5 accuracy 78.000
# val part1: loss 2.354322
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 14 / 100
# train part1: batch 0/29, loss 1.992, top-1 accuracy 42.000, top-5 accuracy 74.000
# train part1: loss 1.959794
# val part1: batch 0/59, loss 3.310, top-1 accuracy 2.000, top-5 accuracy 28.000
# val part1: loss 2.369813
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 15 / 100
# train part1: batch 0/29, loss 1.881, top-1 accuracy 32.000, top-5 accuracy 80.000
# train part1: loss 1.922127
# val part1: batch 0/59, loss 2.827, top-1 accuracy 16.000, top-5 accuracy 48.000
# val part1: loss 2.352942
# Checkpoint saved
# part1 Epoch 16 / 100
# train part1: batch 0/29, loss 1.851, top-1 accuracy 44.000, top-5 accuracy 80.000
# train part1: loss 1.840138
# val part1: batch 0/59, loss 2.802, top-1 accuracy 12.000, top-5 accuracy 50.000
# val part1: loss 2.303088
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 17 / 100
# train part1: batch 0/29, loss 1.823, top-1 accuracy 34.000, top-5 accuracy 82.000
# train part1: loss 1.785216
# val part1: batch 0/59, loss 2.157, top-1 accuracy 22.000, top-5 accuracy 76.000
# val part1: loss 2.304407
# Checkpoint saved
# part1 Epoch 18 / 100
# train part1: batch 0/29, loss 1.637, top-1 accuracy 50.000, top-5 accuracy 86.000
# train part1: loss 1.728734
# val part1: batch 0/59, loss 2.902, top-1 accuracy 10.000, top-5 accuracy 50.000
# val part1: loss 2.289138
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 19 / 100
# train part1: batch 0/29, loss 1.845, top-1 accuracy 42.000, top-5 accuracy 80.000
# train part1: loss 1.700180
# val part1: batch 0/59, loss 2.932, top-1 accuracy 8.000, top-5 accuracy 48.000
# val part1: loss 2.203436
# Checkpoint saved
# part1 Epoch 20 / 100
# train part1: batch 0/29, loss 1.423, top-1 accuracy 68.000, top-5 accuracy 86.000
# train part1: loss 1.636952
# val part1: batch 0/59, loss 2.773, top-1 accuracy 14.000, top-5 accuracy 64.000
# val part1: loss 2.266409
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 21 / 100
# train part1: batch 0/29, loss 1.397, top-1 accuracy 58.000, top-5 accuracy 90.000
# train part1: loss 1.577811
# val part1: batch 0/59, loss 2.497, top-1 accuracy 20.000, top-5 accuracy 66.000
# val part1: loss 2.222506
# Checkpoint saved
# part1 Epoch 22 / 100
# train part1: batch 0/29, loss 1.391, top-1 accuracy 58.000, top-5 accuracy 88.000
# train part1: loss 1.536197
# val part1: batch 0/59, loss 2.930, top-1 accuracy 12.000, top-5 accuracy 50.000
# val part1: loss 2.158306
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 23 / 100
# train part1: batch 0/29, loss 1.285, top-1 accuracy 60.000, top-5 accuracy 92.000
# train part1: loss 1.502447
# val part1: batch 0/59, loss 3.017, top-1 accuracy 14.000, top-5 accuracy 50.000
# val part1: loss 2.252710
# Checkpoint saved
# part1 Epoch 24 / 100
# train part1: batch 0/29, loss 1.483, top-1 accuracy 48.000, top-5 accuracy 92.000
# train part1: loss 1.450506
# val part1: batch 0/59, loss 2.638, top-1 accuracy 18.000, top-5 accuracy 62.000
# val part1: loss 2.238136
# Checkpoint saved
# part1 Epoch 25 / 100
# train part1: batch 0/29, loss 1.354, top-1 accuracy 60.000, top-5 accuracy 92.000
# train part1: loss 1.425514
# val part1: batch 0/59, loss 3.229, top-1 accuracy 16.000, top-5 accuracy 54.000
# val part1: loss 2.269570
# Checkpoint saved
# part1 Epoch 26 / 100
# train part1: batch 0/29, loss 1.567, top-1 accuracy 48.000, top-5 accuracy 94.000
# train part1: loss 1.427972
# val part1: batch 0/59, loss 3.026, top-1 accuracy 16.000, top-5 accuracy 58.000
# val part1: loss 2.323854
# Checkpoint saved
# part1 Epoch 27 / 100
# train part1: batch 0/29, loss 1.275, top-1 accuracy 64.000, top-5 accuracy 88.000
# train part1: loss 1.399597
# val part1: batch 0/59, loss 4.167, top-1 accuracy 6.000, top-5 accuracy 30.000
# val part1: loss 2.253054
# Checkpoint saved
# part1 Epoch 28 / 100
# train part1: batch 0/29, loss 1.158, top-1 accuracy 66.000, top-5 accuracy 92.000
# train part1: loss 1.371859
# val part1: batch 0/59, loss 3.703, top-1 accuracy 8.000, top-5 accuracy 46.000
# val part1: loss 2.382104
# Checkpoint saved
# part1 Epoch 29 / 100
# train part1: batch 0/29, loss 1.140, top-1 accuracy 60.000, top-5 accuracy 96.000
# train part1: loss 1.319602
# val part1: batch 0/59, loss 3.515, top-1 accuracy 12.000, top-5 accuracy 44.000
# val part1: loss 2.368731
# Checkpoint saved
# part1 Epoch 30 / 100
# train part1: batch 0/29, loss 1.283, top-1 accuracy 50.000, top-5 accuracy 98.000
# train part1: loss 1.324347
# val part1: batch 0/59, loss 2.939, top-1 accuracy 16.000, top-5 accuracy 60.000
# val part1: loss 2.381669
# Checkpoint saved
# part1 Epoch 31 / 100
# train part1: batch 0/29, loss 0.910, top-1 accuracy 72.000, top-5 accuracy 96.000
# train part1: loss 1.312700
# val part1: batch 0/59, loss 2.483, top-1 accuracy 28.000, top-5 accuracy 74.000
# val part1: loss 2.399832
# Checkpoint saved
# part1 Epoch 32 / 100
# train part1: batch 0/29, loss 1.114, top-1 accuracy 62.000, top-5 accuracy 96.000
# train part1: loss 1.291613
# val part1: batch 0/59, loss 2.529, top-1 accuracy 30.000, top-5 accuracy 68.000
# val part1: loss 2.334714
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 33 / 100
# train part1: batch 0/29, loss 1.308, top-1 accuracy 54.000, top-5 accuracy 90.000
# train part1: loss 1.203338
# val part1: batch 0/59, loss 3.227, top-1 accuracy 14.000, top-5 accuracy 60.000
# val part1: loss 2.358234
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 34 / 100
# train part1: batch 0/29, loss 1.175, top-1 accuracy 62.000, top-5 accuracy 92.000
# train part1: loss 1.274085
# val part1: batch 0/59, loss 2.572, top-1 accuracy 32.000, top-5 accuracy 74.000
# val part1: loss 2.419880
# Checkpoint saved
# part1 Epoch 35 / 100
# train part1: batch 0/29, loss 1.417, top-1 accuracy 56.000, top-5 accuracy 88.000
# train part1: loss 1.253346
# val part1: batch 0/59, loss 2.907, top-1 accuracy 24.000, top-5 accuracy 66.000
# val part1: loss 2.363290
# Checkpoint saved
# part1 Epoch 36 / 100
# train part1: batch 0/29, loss 1.038, top-1 accuracy 64.000, top-5 accuracy 94.000
# train part1: loss 1.195142
# val part1: batch 0/59, loss 3.532, top-1 accuracy 14.000, top-5 accuracy 60.000
# val part1: loss 2.411036
# Checkpoint saved
# part1 Epoch 37 / 100
# train part1: batch 0/29, loss 1.385, top-1 accuracy 54.000, top-5 accuracy 94.000
# train part1: loss 1.186021
# val part1: batch 0/59, loss 2.744, top-1 accuracy 28.000, top-5 accuracy 72.000
# val part1: loss 2.508178
# Checkpoint saved
# part1 Epoch 38 / 100
# train part1: batch 0/29, loss 0.884, top-1 accuracy 74.000, top-5 accuracy 98.000
# train part1: loss 1.109471
# val part1: batch 0/59, loss 3.382, top-1 accuracy 24.000, top-5 accuracy 56.000
# val part1: loss 2.428968
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 39 / 100
# train part1: batch 0/29, loss 0.986, top-1 accuracy 70.000, top-5 accuracy 94.000
# train part1: loss 1.129305
# val part1: batch 0/59, loss 2.948, top-1 accuracy 22.000, top-5 accuracy 68.000
# val part1: loss 2.414607
# Checkpoint saved
# part1 Epoch 40 / 100
# train part1: batch 0/29, loss 0.948, top-1 accuracy 64.000, top-5 accuracy 98.000
# train part1: loss 1.075339
# val part1: batch 0/59, loss 4.245, top-1 accuracy 12.000, top-5 accuracy 44.000
# val part1: loss 2.479153
# Checkpoint saved
# part1 Epoch 41 / 100
# train part1: batch 0/29, loss 1.360, top-1 accuracy 62.000, top-5 accuracy 84.000
# train part1: loss 1.133397
# val part1: batch 0/59, loss 3.596, top-1 accuracy 16.000, top-5 accuracy 54.000
# val part1: loss 2.418505
# Checkpoint saved
# part1 Epoch 42 / 100
# train part1: batch 0/29, loss 0.999, top-1 accuracy 68.000, top-5 accuracy 100.000
# train part1: loss 1.095697
# val part1: batch 0/59, loss 2.980, top-1 accuracy 26.000, top-5 accuracy 74.000
# val part1: loss 2.543775
# Checkpoint saved
# part1 Epoch 43 / 100
# train part1: batch 0/29, loss 1.239, top-1 accuracy 68.000, top-5 accuracy 88.000
# train part1: loss 1.090263
# val part1: batch 0/59, loss 3.100, top-1 accuracy 24.000, top-5 accuracy 68.000
# val part1: loss 2.535703
# Checkpoint saved
# part1 Epoch 44 / 100
# train part1: batch 0/29, loss 1.062, top-1 accuracy 64.000, top-5 accuracy 96.000
# train part1: loss 1.017708
# val part1: batch 0/59, loss 4.319, top-1 accuracy 14.000, top-5 accuracy 42.000
# val part1: loss 2.434195
# Checkpoint saved
# part1 Epoch 45 / 100
# train part1: batch 0/29, loss 0.970, top-1 accuracy 70.000, top-5 accuracy 96.000
# train part1: loss 0.990239
# val part1: batch 0/59, loss 3.215, top-1 accuracy 24.000, top-5 accuracy 66.000
# val part1: loss 2.558188
# Checkpoint saved
# part1 Epoch 46 / 100
# train part1: batch 0/29, loss 0.837, top-1 accuracy 72.000, top-5 accuracy 96.000
# train part1: loss 0.946994
# val part1: batch 0/59, loss 3.236, top-1 accuracy 24.000, top-5 accuracy 64.000
# val part1: loss 2.621978
# Checkpoint saved
# part1 Epoch 47 / 100
# train part1: batch 0/29, loss 0.878, top-1 accuracy 72.000, top-5 accuracy 98.000
# train part1: loss 0.937572
# val part1: batch 0/59, loss 3.513, top-1 accuracy 20.000, top-5 accuracy 54.000
# val part1: loss 2.488293
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 48 / 100
# train part1: batch 0/29, loss 0.615, top-1 accuracy 84.000, top-5 accuracy 98.000
# train part1: loss 0.932625
# val part1: batch 0/59, loss 3.527, top-1 accuracy 22.000, top-5 accuracy 54.000
# val part1: loss 2.563229
# Checkpoint saved
# part1 Epoch 49 / 100
# train part1: batch 0/29, loss 0.609, top-1 accuracy 78.000, top-5 accuracy 100.000
# train part1: loss 0.888968
# val part1: batch 0/59, loss 3.979, top-1 accuracy 14.000, top-5 accuracy 52.000
# val part1: loss 2.555118
# Checkpoint saved
# part1 Epoch 50 / 100
# train part1: batch 0/29, loss 0.869, top-1 accuracy 70.000, top-5 accuracy 98.000
# train part1: loss 0.893557
# val part1: batch 0/59, loss 4.303, top-1 accuracy 14.000, top-5 accuracy 54.000
# val part1: loss 2.816518
# Checkpoint saved
# part1 Epoch 51 / 100
# train part1: batch 0/29, loss 1.071, top-1 accuracy 66.000, top-5 accuracy 100.000
# train part1: loss 0.861984
# val part1: batch 0/59, loss 3.321, top-1 accuracy 26.000, top-5 accuracy 68.000
# val part1: loss 2.670231
# Checkpoint saved
# part1 Epoch 52 / 100
# train part1: batch 0/29, loss 0.844, top-1 accuracy 74.000, top-5 accuracy 94.000
# train part1: loss 0.875866
# val part1: batch 0/59, loss 4.844, top-1 accuracy 12.000, top-5 accuracy 42.000
# val part1: loss 2.701734
# Checkpoint saved
# part1 Epoch 53 / 100
# train part1: batch 0/29, loss 0.862, top-1 accuracy 74.000, top-5 accuracy 98.000
# train part1: loss 0.853296
# val part1: batch 0/59, loss 3.667, top-1 accuracy 20.000, top-5 accuracy 66.000
# val part1: loss 2.765514
# Checkpoint saved
# part1 Epoch 54 / 100
# train part1: batch 0/29, loss 0.879, top-1 accuracy 72.000, top-5 accuracy 96.000
# train part1: loss 0.775246
# val part1: batch 0/59, loss 4.591, top-1 accuracy 14.000, top-5 accuracy 44.000
# val part1: loss 2.629961
# Checkpoint saved
# part1 Epoch 55 / 100
# train part1: batch 0/29, loss 0.629, top-1 accuracy 80.000, top-5 accuracy 100.000
# train part1: loss 0.751633
# val part1: batch 0/59, loss 3.713, top-1 accuracy 20.000, top-5 accuracy 62.000
# val part1: loss 2.835460
# Checkpoint saved
# part1 Epoch 56 / 100
# train part1: batch 0/29, loss 0.952, top-1 accuracy 66.000, top-5 accuracy 98.000
# train part1: loss 0.744916
# val part1: batch 0/59, loss 3.961, top-1 accuracy 18.000, top-5 accuracy 60.000
# val part1: loss 2.919909
# Checkpoint saved
# part1 Epoch 57 / 100
# train part1: batch 0/29, loss 0.704, top-1 accuracy 68.000, top-5 accuracy 98.000
# train part1: loss 0.688295
# val part1: batch 0/59, loss 3.890, top-1 accuracy 20.000, top-5 accuracy 66.000
# val part1: loss 2.741826
# Checkpoint saved
# part1 Epoch 58 / 100
# train part1: batch 0/29, loss 0.457, top-1 accuracy 84.000, top-5 accuracy 100.000
# train part1: loss 0.693547
# val part1: batch 0/59, loss 4.269, top-1 accuracy 18.000, top-5 accuracy 60.000
# val part1: loss 2.873592
# Checkpoint saved
# part1 Epoch 59 / 100
# train part1: batch 0/29, loss 0.599, top-1 accuracy 82.000, top-5 accuracy 100.000
# train part1: loss 0.704214
# val part1: batch 0/59, loss 4.594, top-1 accuracy 16.000, top-5 accuracy 46.000
# val part1: loss 2.860695
# Checkpoint saved
# part1 Epoch 60 / 100
# train part1: batch 0/29, loss 0.755, top-1 accuracy 78.000, top-5 accuracy 96.000
# train part1: loss 0.557300
# val part1: batch 0/59, loss 4.187, top-1 accuracy 16.000, top-5 accuracy 56.000
# val part1: loss 2.774264
# Checkpoint saved
# part1 Epoch 61 / 100
# train part1: batch 0/29, loss 0.443, top-1 accuracy 90.000, top-5 accuracy 100.000
# train part1: loss 0.518039
# val part1: batch 0/59, loss 4.295, top-1 accuracy 16.000, top-5 accuracy 56.000
# val part1: loss 2.780554
# Checkpoint saved
# part1 Epoch 62 / 100
# train part1: batch 0/29, loss 0.505, top-1 accuracy 90.000, top-5 accuracy 100.000
# train part1: loss 0.505367
# val part1: batch 0/59, loss 4.258, top-1 accuracy 18.000, top-5 accuracy 54.000
# val part1: loss 2.804852
# Checkpoint saved
# part1 Epoch 63 / 100
# train part1: batch 0/29, loss 0.452, top-1 accuracy 92.000, top-5 accuracy 100.000
# train part1: loss 0.502875
# val part1: batch 0/59, loss 4.409, top-1 accuracy 18.000, top-5 accuracy 54.000
# val part1: loss 2.798175
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 64 / 100
# train part1: batch 0/29, loss 0.514, top-1 accuracy 84.000, top-5 accuracy 98.000
# train part1: loss 0.494496
# val part1: batch 0/59, loss 4.301, top-1 accuracy 18.000, top-5 accuracy 54.000
# val part1: loss 2.814759
# Checkpoint saved
# part1 Epoch 65 / 100
# train part1: batch 0/29, loss 0.429, top-1 accuracy 84.000, top-5 accuracy 98.000
# train part1: loss 0.491633
# val part1: batch 0/59, loss 4.497, top-1 accuracy 18.000, top-5 accuracy 48.000
# val part1: loss 2.789931
# Checkpoint saved
# part1 Epoch 66 / 100
# train part1: batch 0/29, loss 0.558, top-1 accuracy 88.000, top-5 accuracy 98.000
# train part1: loss 0.489282
# val part1: batch 0/59, loss 4.268, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 2.806203
# Checkpoint saved
# part1 Epoch 67 / 100
# train part1: batch 0/29, loss 0.445, top-1 accuracy 90.000, top-5 accuracy 100.000
# train part1: loss 0.489051
# val part1: batch 0/59, loss 4.359, top-1 accuracy 18.000, top-5 accuracy 50.000
# val part1: loss 2.818487
# Checkpoint saved
# part1 Epoch 68 / 100
# train part1: batch 0/29, loss 0.598, top-1 accuracy 82.000, top-5 accuracy 98.000
# train part1: loss 0.488552
# val part1: batch 0/59, loss 4.328, top-1 accuracy 18.000, top-5 accuracy 54.000
# val part1: loss 2.801368
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 69 / 100
# train part1: batch 0/29, loss 0.500, top-1 accuracy 90.000, top-5 accuracy 96.000
# train part1: loss 0.481837
# val part1: batch 0/59, loss 4.409, top-1 accuracy 18.000, top-5 accuracy 52.000
# val part1: loss 2.812801
# Checkpoint saved
# part1 Epoch 70 / 100
# train part1: batch 0/29, loss 0.494, top-1 accuracy 88.000, top-5 accuracy 100.000
# train part1: loss 0.479071
# val part1: batch 0/59, loss 4.347, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 2.816502
# Checkpoint saved
# part1 Epoch 71 / 100
# train part1: batch 0/29, loss 0.315, top-1 accuracy 96.000, top-5 accuracy 98.000
# train part1: loss 0.477557
# val part1: batch 0/59, loss 4.369, top-1 accuracy 16.000, top-5 accuracy 58.000
# val part1: loss 2.838948
# Checkpoint saved
# part1 Epoch 72 / 100
# train part1: batch 0/29, loss 0.447, top-1 accuracy 86.000, top-5 accuracy 100.000
# train part1: loss 0.476961
# val part1: batch 0/59, loss 4.533, top-1 accuracy 18.000, top-5 accuracy 48.000
# val part1: loss 2.815750
# Checkpoint saved
# part1 Epoch 73 / 100
# train part1: batch 0/29, loss 0.468, top-1 accuracy 90.000, top-5 accuracy 98.000
# train part1: loss 0.473417
# val part1: batch 0/59, loss 4.601, top-1 accuracy 18.000, top-5 accuracy 46.000
# val part1: loss 2.828394
# Checkpoint saved
# part1 Epoch 74 / 100
# train part1: batch 0/29, loss 0.464, top-1 accuracy 92.000, top-5 accuracy 98.000
# train part1: loss 0.468981
# val part1: batch 0/59, loss 4.339, top-1 accuracy 16.000, top-5 accuracy 60.000
# val part1: loss 2.840946
# Checkpoint saved
# part1 Epoch 75 / 100
# train part1: batch 0/29, loss 0.467, top-1 accuracy 90.000, top-5 accuracy 100.000
# train part1: loss 0.469753
# val part1: batch 0/59, loss 4.431, top-1 accuracy 18.000, top-5 accuracy 52.000
# val part1: loss 2.837540
# Checkpoint saved
# part1 Epoch 76 / 100
# train part1: batch 0/29, loss 0.337, top-1 accuracy 92.000, top-5 accuracy 100.000
# train part1: loss 0.464878
# val part1: batch 0/59, loss 4.182, top-1 accuracy 20.000, top-5 accuracy 58.000
# val part1: loss 2.863606
# Checkpoint saved
# part1 Epoch 77 / 100
# train part1: batch 0/29, loss 0.313, top-1 accuracy 98.000, top-5 accuracy 100.000
# train part1: loss 0.462391
# val part1: batch 0/59, loss 4.560, top-1 accuracy 18.000, top-5 accuracy 50.000
# val part1: loss 2.829527
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 78 / 100
# train part1: batch 0/29, loss 0.582, top-1 accuracy 90.000, top-5 accuracy 96.000
# train part1: loss 0.461734
# val part1: batch 0/59, loss 4.543, top-1 accuracy 18.000, top-5 accuracy 52.000
# val part1: loss 2.842267
# Checkpoint saved
# part1 Epoch 79 / 100
# train part1: batch 0/29, loss 0.406, top-1 accuracy 96.000, top-5 accuracy 100.000
# train part1: loss 0.459982
# val part1: batch 0/59, loss 4.283, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 2.856423
# Checkpoint saved
# part1 Epoch 80 / 100
# train part1: batch 0/29, loss 0.355, top-1 accuracy 92.000, top-5 accuracy 100.000
# train part1: loss 0.455141
# val part1: batch 0/59, loss 4.431, top-1 accuracy 18.000, top-5 accuracy 56.000
# val part1: loss 2.851917
# Checkpoint saved
# part1 Epoch 81 / 100
# train part1: batch 0/29, loss 0.499, top-1 accuracy 86.000, top-5 accuracy 100.000
# train part1: loss 0.459044
# val part1: batch 0/59, loss 4.504, top-1 accuracy 18.000, top-5 accuracy 54.000
# val part1: loss 2.863588
# Checkpoint saved
# part1 Epoch 82 / 100
# train part1: batch 0/29, loss 0.359, top-1 accuracy 94.000, top-5 accuracy 100.000
# train part1: loss 0.454941
# val part1: batch 0/59, loss 4.293, top-1 accuracy 18.000, top-5 accuracy 56.000
# val part1: loss 2.859361
# Checkpoint saved
# part1 Epoch 83 / 100
# train part1: batch 0/29, loss 0.335, top-1 accuracy 92.000, top-5 accuracy 100.000
# train part1: loss 0.455607
# val part1: batch 0/59, loss 4.174, top-1 accuracy 20.000, top-5 accuracy 60.000
# val part1: loss 2.881558
# Checkpoint saved
# part1 Epoch 84 / 100
# train part1: batch 0/29, loss 0.391, top-1 accuracy 96.000, top-5 accuracy 100.000
# train part1: loss 0.449959
# val part1: batch 0/59, loss 4.260, top-1 accuracy 18.000, top-5 accuracy 56.000
# val part1: loss 2.866988
# Checkpoint saved
# part1 Epoch 85 / 100
# train part1: batch 0/29, loss 0.381, top-1 accuracy 94.000, top-5 accuracy 98.000
# train part1: loss 0.447667
# val part1: batch 0/59, loss 4.632, top-1 accuracy 18.000, top-5 accuracy 48.000
# val part1: loss 2.864628
# Checkpoint saved
# part1 Epoch 86 / 100
# train part1: batch 0/29, loss 0.401, top-1 accuracy 92.000, top-5 accuracy 100.000
# train part1: loss 0.448963
# val part1: batch 0/59, loss 4.486, top-1 accuracy 16.000, top-5 accuracy 54.000
# val part1: loss 2.882471
# Checkpoint saved
# part1 Epoch 87 / 100
# train part1: batch 0/29, loss 0.450, top-1 accuracy 92.000, top-5 accuracy 100.000
# train part1: loss 0.447849
# val part1: batch 0/59, loss 4.332, top-1 accuracy 18.000, top-5 accuracy 60.000
# val part1: loss 2.899516
# Checkpoint saved
# part1 Epoch 88 / 100
# train part1: batch 0/29, loss 0.381, top-1 accuracy 94.000, top-5 accuracy 100.000
# train part1: loss 0.441661
# val part1: batch 0/59, loss 4.534, top-1 accuracy 18.000, top-5 accuracy 50.000
# val part1: loss 2.868597
# Checkpoint saved
# part1 Epoch 89 / 100
# train part1: batch 0/29, loss 0.491, top-1 accuracy 94.000, top-5 accuracy 98.000
# train part1: loss 0.440481
# val part1: batch 0/59, loss 4.243, top-1 accuracy 20.000, top-5 accuracy 60.000
# val part1: loss 2.901859
# Checkpoint saved
# part1 Epoch 90 / 100
# train part1: batch 0/29, loss 0.332, top-1 accuracy 98.000, top-5 accuracy 100.000
# train part1: loss 0.440316
# val part1: batch 0/59, loss 4.328, top-1 accuracy 18.000, top-5 accuracy 52.000
# val part1: loss 2.913510
# Checkpoint saved
# part1 Epoch 91 / 100
# train part1: batch 0/29, loss 0.387, top-1 accuracy 94.000, top-5 accuracy 100.000
# train part1: loss 0.439160
# val part1: batch 0/59, loss 4.525, top-1 accuracy 18.000, top-5 accuracy 52.000
# val part1: loss 2.888553
# Checkpoint saved
# part1 Epoch 92 / 100
# train part1: batch 0/29, loss 0.383, top-1 accuracy 94.000, top-5 accuracy 100.000
# train part1: loss 0.433133
# val part1: batch 0/59, loss 4.596, top-1 accuracy 18.000, top-5 accuracy 52.000
# val part1: loss 2.887776
# Checkpoint saved
# part1 Epoch 93 / 100
# train part1: batch 0/29, loss 0.400, top-1 accuracy 94.000, top-5 accuracy 98.000
# train part1: loss 0.433474
# val part1: batch 0/59, loss 4.666, top-1 accuracy 18.000, top-5 accuracy 48.000
# val part1: loss 2.895877
# Checkpoint saved
# part1 Epoch 94 / 100
# train part1: batch 0/29, loss 0.401, top-1 accuracy 88.000, top-5 accuracy 100.000
# train part1: loss 0.429900
# val part1: batch 0/59, loss 4.720, top-1 accuracy 18.000, top-5 accuracy 50.000
# val part1: loss 2.906040
# Checkpoint saved
# part1 Epoch 95 / 100
# train part1: batch 0/29, loss 0.508, top-1 accuracy 90.000, top-5 accuracy 100.000
# train part1: loss 0.428405
# val part1: batch 0/59, loss 4.645, top-1 accuracy 18.000, top-5 accuracy 56.000
# val part1: loss 2.906188
# Checkpoint saved
# part1 Epoch 96 / 100
# train part1: batch 0/29, loss 0.436, top-1 accuracy 92.000, top-5 accuracy 98.000
# train part1: loss 0.425091
# val part1: batch 0/59, loss 4.177, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 2.928361
# Checkpoint saved
# part1 Epoch 97 / 100
# train part1: batch 0/29, loss 0.472, top-1 accuracy 92.000, top-5 accuracy 98.000
# train part1: loss 0.425078
# val part1: batch 0/59, loss 4.562, top-1 accuracy 18.000, top-5 accuracy 56.000
# val part1: loss 2.913262
# Checkpoint saved
# part1 Epoch 98 / 100
# train part1: batch 0/29, loss 0.599, top-1 accuracy 82.000, top-5 accuracy 98.000
# train part1: loss 0.421742
# val part1: batch 0/59, loss 4.234, top-1 accuracy 18.000, top-5 accuracy 60.000
# val part1: loss 2.937538
# Checkpoint saved
# part1 Epoch 99 / 100
# train part1: batch 0/29, loss 0.438, top-1 accuracy 92.000, top-5 accuracy 100.000
# train part1: loss 0.425302
# val part1: batch 0/59, loss 4.503, top-1 accuracy 18.000, top-5 accuracy 56.000
# val part1: loss 2.921447
# Checkpoint saved
# Best top-1 Accuracy = 36.382

# %% [markdown]
# Expect this code to take around 5 minutes on CPU or 3 minutes on GPU. Now you are ready to actually modify the functions we used to train our model. Before you move on, make sure to record the accuracy of your network from Part 0, and report it in your write up.

# %% [markdown]
# ## Part 1: Modifying the Dataloaders and the Simple Network create_datasets

# %%
# Fix random seeds so that results will be reproducible
set_seed(0, use_GPU)

# %% [markdown]
# Now you will modify the create_datasets function from student_code. You will add random left-right mirroring and normalization to the transformations applied to the training dataset. You will also add normalization to the transformations applied to the testing dataset.

# %%
# Create the training and testing datasets.
train_dataset, test_dataset = sc.create_datasets(data_path=data_path, input_size=input_size, rgb=RGB)
assert test_dataset.classes == train_dataset.classes
# Out:
# Computing pixel mean and stdev...
# Batch 0 / 30
# Batch 20 / 30
# Done, mean =
# [0.45579668]
# std =
# [0.23624939]
# Computing pixel mean and stdev...
# Batch 0 / 60
# Batch 20 / 60
# Batch 40 / 60
# Done, mean =
# [0.45517009]
# std =
# [0.2350788]

# %% [markdown]
# Now you will modify SimpleNet by adding droppout, batch normalization, and additional convolution/maxpool/relu layers. You should achieve an accuracy of at least **50%**. Make sure your network passes this threshold--it is required for full credit on this section!
#
# You can also use the following two blocks to determine the stucture of your network.

# %%
# create the network model
model = sc.SimpleNet(num_classes=num_classes, rgb=False, verbose=False)
if use_GPU:
    model = model.cuda()
print(model)
# Out:
# SimpleNet(
#   (features): Sequential(
#     (0): Conv2d(1, 10, kernel_size=(9, 9), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): MaxPool2d(kernel_size=7, stride=7, padding=0, dilation=1, ceil_mode=False)
#     (3): ReLU()
#     (4): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): Conv2d(10, 10, kernel_size=(5, 5), stride=(1, 1), bias=False)
#     (6): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): MaxPool2d(kernel_size=3, stride=1, padding=0, dilation=1, ceil_mode=False)
#     (8): ReLU()
#     (9): Dropout(p=0.5)
#   )
#   (classifier): Conv2d(10, 15, kernel_size=(2, 2), stride=(1, 1))
# )

# %%
# Use this block to determine the kernel size of the conv2d layer in the classifier
# first, set the kernel size of that conv2d layer to 1, and run this block
# then, use that size of input to the classifier printed by this block to
# go back and update the kernel size of the conv2d layer in the classifier
# Finally, run this block again and verify that the network output size is a scalar
# Don't forget to re-run the block above every time you update the SimpleNet class!
from torch.autograd import Variable
data, _ = train_dataset[0]
s = data.size()
data = Variable(data.view(1, *s))
if use_GPU:
    data = data.cuda()
out = model(data)
print('Network output size is ', out.size())
# Out:
# Network output size is  torch.Size([15])

# %% [markdown]
# Next we will create the loss function and the optimizer. You do not have to modify the custom_part1_trainer in student_code if you use the same loss_function, optimizer, scheduler and parameters (n_epoch, batch_size etc.) as provided in this notebook to hit the required threshold of 50% accuracy. If you changed any of these values, it is important that you modify this function in student_code since we will not be using the notebook you submit to evaluate.

# %%
# Set up the trainer. You can modify custom_part1_trainer in
# student_copy.py if you want to try different learning settings.
custom_part1_trainer = sc.custom_part1_trainer(model)

if custom_part1_trainer is None:
    # Create the loss function.
    # see http://pytorch.org/docs/0.3.0/nn.html#loss-functions for a list of available loss functions
    loss_function = nn.CrossEntropyLoss()

    # Create the optimizer and a learning rate scheduler.
    optimizer = optim.SGD(params=model.parameters(), lr=base_lr, weight_decay=weight_decay, momentum=momentum)
    # Currently a simple step scheduler, but you can get creative.
    # See http://pytorch.org/docs/0.3.0/optim.html#how-to-adjust-learning-rate for various LR schedulers
    # and how to use them
    lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=60, gamma=0.1)

    params = {'n_epochs': 100, 'batch_size': 50, 'experiment': 'part1'}
    
else:
    if 'loss_function' in custom_part1_trainer:
        loss_function = custom_part1_trainer['loss_function']
    if 'optimizer' in custom_part1_trainer:
        optimizer = custom_part1_trainer['optimizer']
    if 'lr_scheduler' in custom_part1_trainer:
        lr_scheduler = custom_part1_trainer['lr_scheduler']
    if 'params' in custom_part1_trainer:
        params = custom_part1_trainer['params']

# %% [markdown]
# We are ready to train our network! As before, we will start a local server to see the training progress of our network (if you server is already running, you should not start another one). Open a new terminal and activate the environment for this project. Then run the following command: **python -m visdom.server**. This will start a local server. The terminal output should give out a link like: "http://localhost:8097". Open this link in your browser. After you run the following block, visit this link again, and you will be able to see graphs showing the progress of your training! If you do not see any graphs, select Part 1 on the top left bar where is says Environment (only select Part 1, do not check main or Part 2).

# %%
# Train the network!
trainer = Trainer(train_dataset, test_dataset, model, loss_function, optimizer, lr_scheduler, params)
best_prec1 = trainer.train_val()
print('Best top-1 Accuracy = {:4.3f}'.format(best_prec1))
# Out:
# ---------------------------------------
# Experiment: part1
# experiment: part1
# checkpoint_file: None
# n_epochs: 100
# resume_optim: True
# do_val: True
# print_freq: 100
# val_freq: 1
# shuffle: True
# num_workers: 4
# batch_size: 50
# ---------------------------------------
# part1 Epoch 0 / 100
# train part1: batch 0/29, loss 2.693, top-1 accuracy 4.000, top-5 accuracy 42.000
# train part1: loss 2.642001
# val part1: batch 0/59, loss 2.443, top-1 accuracy 20.000, top-5 accuracy 72.000
# val part1: loss 2.405273
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 1 / 100
# train part1: batch 0/29, loss 2.373, top-1 accuracy 20.000, top-5 accuracy 70.000
# train part1: loss 2.472300
# val part1: batch 0/59, loss 2.718, top-1 accuracy 6.000, top-5 accuracy 36.000
# val part1: loss 2.323048
# Checkpoint saved
# part1 Epoch 2 / 100
# train part1: batch 0/29, loss 2.578, top-1 accuracy 10.000, top-5 accuracy 52.000
# train part1: loss 2.359621
# val part1: batch 0/59, loss 2.934, top-1 accuracy 2.000, top-5 accuracy 28.000
# val part1: loss 2.152513
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 3 / 100
# train part1: batch 0/29, loss 2.166, top-1 accuracy 38.000, top-5 accuracy 72.000
# train part1: loss 2.289977
# val part1: batch 0/59, loss 2.170, top-1 accuracy 36.000, top-5 accuracy 76.000
# val part1: loss 2.152218
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 4 / 100
# train part1: batch 0/29, loss 2.387, top-1 accuracy 22.000, top-5 accuracy 68.000
# train part1: loss 2.200111
# val part1: batch 0/59, loss 2.418, top-1 accuracy 6.000, top-5 accuracy 64.000
# val part1: loss 2.036560
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 5 / 100
# train part1: batch 0/29, loss 2.109, top-1 accuracy 20.000, top-5 accuracy 78.000
# train part1: loss 2.211582
# val part1: batch 0/59, loss 2.273, top-1 accuracy 22.000, top-5 accuracy 68.000
# val part1: loss 2.120328
# Checkpoint saved
# part1 Epoch 6 / 100
# train part1: batch 0/29, loss 2.189, top-1 accuracy 26.000, top-5 accuracy 66.000
# train part1: loss 2.172630
# val part1: batch 0/59, loss 2.193, top-1 accuracy 30.000, top-5 accuracy 74.000
# val part1: loss 1.990881
# Checkpoint saved
# part1 Epoch 7 / 100
# train part1: batch 0/29, loss 1.963, top-1 accuracy 34.000, top-5 accuracy 76.000
# train part1: loss 2.143146
# val part1: batch 0/59, loss 2.224, top-1 accuracy 18.000, top-5 accuracy 82.000
# val part1: loss 2.016864
# Checkpoint saved
# part1 Epoch 8 / 100
# train part1: batch 0/29, loss 2.113, top-1 accuracy 42.000, top-5 accuracy 72.000
# train part1: loss 2.109149
# val part1: batch 0/59, loss 1.901, top-1 accuracy 46.000, top-5 accuracy 86.000
# val part1: loss 1.992862
# Checkpoint saved
# part1 Epoch 9 / 100
# train part1: batch 0/29, loss 2.164, top-1 accuracy 18.000, top-5 accuracy 76.000
# train part1: loss 2.051859
# val part1: batch 0/59, loss 2.165, top-1 accuracy 24.000, top-5 accuracy 70.000
# val part1: loss 1.885434
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 10 / 100
# train part1: batch 0/29, loss 1.843, top-1 accuracy 40.000, top-5 accuracy 78.000
# train part1: loss 2.000360
# val part1: batch 0/59, loss 2.339, top-1 accuracy 26.000, top-5 accuracy 62.000
# val part1: loss 1.860234
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 11 / 100
# train part1: batch 0/29, loss 1.940, top-1 accuracy 32.000, top-5 accuracy 84.000
# train part1: loss 2.005949
# val part1: batch 0/59, loss 1.837, top-1 accuracy 46.000, top-5 accuracy 84.000
# val part1: loss 1.862613
# Checkpoint saved
# part1 Epoch 12 / 100
# train part1: batch 0/29, loss 1.881, top-1 accuracy 36.000, top-5 accuracy 82.000
# train part1: loss 2.011884
# val part1: batch 0/59, loss 2.559, top-1 accuracy 6.000, top-5 accuracy 64.000
# val part1: loss 1.855924
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 13 / 100
# train part1: batch 0/29, loss 2.266, top-1 accuracy 28.000, top-5 accuracy 74.000
# train part1: loss 1.971070
# val part1: batch 0/59, loss 1.849, top-1 accuracy 50.000, top-5 accuracy 82.000
# val part1: loss 1.904829
# Checkpoint saved
# part1 Epoch 14 / 100
# train part1: batch 0/29, loss 1.650, top-1 accuracy 42.000, top-5 accuracy 92.000
# train part1: loss 1.977355
# val part1: batch 0/59, loss 2.242, top-1 accuracy 22.000, top-5 accuracy 66.000
# val part1: loss 1.868841
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 15 / 100
# train part1: batch 0/29, loss 1.786, top-1 accuracy 32.000, top-5 accuracy 84.000
# train part1: loss 1.940041
# val part1: batch 0/59, loss 1.972, top-1 accuracy 32.000, top-5 accuracy 80.000
# val part1: loss 1.853919
# Checkpoint saved
# part1 Epoch 16 / 100
# train part1: batch 0/29, loss 1.812, top-1 accuracy 36.000, top-5 accuracy 82.000
# train part1: loss 1.882288
# val part1: batch 0/59, loss 2.173, top-1 accuracy 18.000, top-5 accuracy 74.000
# val part1: loss 1.828551
# Checkpoint saved
# part1 Epoch 17 / 100
# train part1: batch 0/29, loss 2.018, top-1 accuracy 28.000, top-5 accuracy 76.000
# train part1: loss 1.877974
# val part1: batch 0/59, loss 1.758, top-1 accuracy 46.000, top-5 accuracy 88.000
# val part1: loss 1.794060
# Checkpoint saved
# part1 Epoch 18 / 100
# train part1: batch 0/29, loss 1.807, top-1 accuracy 36.000, top-5 accuracy 88.000
# train part1: loss 1.855288
# val part1: batch 0/59, loss 1.989, top-1 accuracy 36.000, top-5 accuracy 74.000
# val part1: loss 1.778554
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 19 / 100
# train part1: batch 0/29, loss 1.710, top-1 accuracy 32.000, top-5 accuracy 84.000
# train part1: loss 1.837714
# val part1: batch 0/59, loss 2.174, top-1 accuracy 24.000, top-5 accuracy 72.000
# val part1: loss 1.791098
# Checkpoint saved
# part1 Epoch 20 / 100
# train part1: batch 0/29, loss 2.014, top-1 accuracy 26.000, top-5 accuracy 78.000
# train part1: loss 1.877336
# val part1: batch 0/59, loss 1.913, top-1 accuracy 34.000, top-5 accuracy 76.000
# val part1: loss 1.742896
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 21 / 100
# train part1: batch 0/29, loss 1.784, top-1 accuracy 40.000, top-5 accuracy 90.000
# train part1: loss 1.860232
# val part1: batch 0/59, loss 2.101, top-1 accuracy 24.000, top-5 accuracy 74.000
# val part1: loss 1.774700
# Checkpoint saved
# part1 Epoch 22 / 100
# train part1: batch 0/29, loss 1.933, top-1 accuracy 38.000, top-5 accuracy 84.000
# train part1: loss 1.829636
# val part1: batch 0/59, loss 1.905, top-1 accuracy 38.000, top-5 accuracy 84.000
# val part1: loss 1.727048
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 23 / 100
# train part1: batch 0/29, loss 1.792, top-1 accuracy 42.000, top-5 accuracy 84.000
# train part1: loss 1.790861
# val part1: batch 0/59, loss 1.993, top-1 accuracy 30.000, top-5 accuracy 80.000
# val part1: loss 1.779157
# Checkpoint saved
# part1 Epoch 24 / 100
# train part1: batch 0/29, loss 1.883, top-1 accuracy 36.000, top-5 accuracy 78.000
# train part1: loss 1.814198
# val part1: batch 0/59, loss 2.136, top-1 accuracy 16.000, top-5 accuracy 78.000
# val part1: loss 1.754849
# Checkpoint saved
# part1 Epoch 25 / 100
# train part1: batch 0/29, loss 1.743, top-1 accuracy 48.000, top-5 accuracy 86.000
# train part1: loss 1.754695
# val part1: batch 0/59, loss 2.074, top-1 accuracy 24.000, top-5 accuracy 82.000
# val part1: loss 1.664552
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 26 / 100
# train part1: batch 0/29, loss 1.718, top-1 accuracy 42.000, top-5 accuracy 86.000
# train part1: loss 1.763746
# val part1: batch 0/59, loss 2.106, top-1 accuracy 20.000, top-5 accuracy 82.000
# val part1: loss 1.717391
# Checkpoint saved
# part1 Epoch 27 / 100
# train part1: batch 0/29, loss 1.923, top-1 accuracy 34.000, top-5 accuracy 78.000
# train part1: loss 1.771625
# val part1: batch 0/59, loss 1.651, top-1 accuracy 62.000, top-5 accuracy 88.000
# val part1: loss 1.699023
# Checkpoint saved
# part1 Epoch 28 / 100
# train part1: batch 0/29, loss 2.134, top-1 accuracy 36.000, top-5 accuracy 76.000
# train part1: loss 1.742808
# val part1: batch 0/59, loss 2.361, top-1 accuracy 12.000, top-5 accuracy 66.000
# val part1: loss 1.683768
# Checkpoint saved
# part1 Epoch 29 / 100
# train part1: batch 0/29, loss 1.549, top-1 accuracy 58.000, top-5 accuracy 88.000
# train part1: loss 1.727622
# val part1: batch 0/59, loss 1.920, top-1 accuracy 24.000, top-5 accuracy 82.000
# val part1: loss 1.725920
# Checkpoint saved
# part1 Epoch 30 / 100
# train part1: batch 0/29, loss 1.606, top-1 accuracy 52.000, top-5 accuracy 86.000
# train part1: loss 1.691554
# val part1: batch 0/59, loss 1.788, top-1 accuracy 38.000, top-5 accuracy 78.000
# val part1: loss 1.681761
# Checkpoint saved
# part1 Epoch 31 / 100
# train part1: batch 0/29, loss 1.798, top-1 accuracy 40.000, top-5 accuracy 88.000
# train part1: loss 1.749593
# val part1: batch 0/59, loss 2.013, top-1 accuracy 30.000, top-5 accuracy 76.000
# val part1: loss 1.640454
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 32 / 100
# train part1: batch 0/29, loss 2.013, top-1 accuracy 36.000, top-5 accuracy 74.000
# train part1: loss 1.731893
# val part1: batch 0/59, loss 2.130, top-1 accuracy 16.000, top-5 accuracy 72.000
# val part1: loss 1.622973
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 33 / 100
# train part1: batch 0/29, loss 1.677, top-1 accuracy 46.000, top-5 accuracy 84.000
# train part1: loss 1.665459
# val part1: batch 0/59, loss 2.020, top-1 accuracy 26.000, top-5 accuracy 78.000
# val part1: loss 1.614433
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 34 / 100
# train part1: batch 0/29, loss 1.629, top-1 accuracy 46.000, top-5 accuracy 88.000
# train part1: loss 1.675020
# val part1: batch 0/59, loss 1.886, top-1 accuracy 30.000, top-5 accuracy 80.000
# val part1: loss 1.610329
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 35 / 100
# train part1: batch 0/29, loss 1.655, top-1 accuracy 44.000, top-5 accuracy 88.000
# train part1: loss 1.680873
# val part1: batch 0/59, loss 2.017, top-1 accuracy 28.000, top-5 accuracy 74.000
# val part1: loss 1.580488
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 36 / 100
# train part1: batch 0/29, loss 1.502, top-1 accuracy 50.000, top-5 accuracy 90.000
# train part1: loss 1.623632
# val part1: batch 0/59, loss 1.908, top-1 accuracy 24.000, top-5 accuracy 80.000
# val part1: loss 1.583999
# Checkpoint saved
# part1 Epoch 37 / 100
# train part1: batch 0/29, loss 1.760, top-1 accuracy 40.000, top-5 accuracy 84.000
# train part1: loss 1.612605
# val part1: batch 0/59, loss 2.025, top-1 accuracy 16.000, top-5 accuracy 80.000
# val part1: loss 1.574967
# Checkpoint saved
# part1 Epoch 38 / 100
# train part1: batch 0/29, loss 1.397, top-1 accuracy 66.000, top-5 accuracy 92.000
# train part1: loss 1.564382
# val part1: batch 0/59, loss 1.866, top-1 accuracy 28.000, top-5 accuracy 84.000
# val part1: loss 1.571607
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 39 / 100
# train part1: batch 0/29, loss 1.319, top-1 accuracy 62.000, top-5 accuracy 94.000
# train part1: loss 1.614283
# val part1: batch 0/59, loss 1.955, top-1 accuracy 30.000, top-5 accuracy 78.000
# val part1: loss 1.562763
# Checkpoint saved
# part1 Epoch 40 / 100
# train part1: batch 0/29, loss 1.701, top-1 accuracy 58.000, top-5 accuracy 86.000
# train part1: loss 1.592034
# val part1: batch 0/59, loss 1.811, top-1 accuracy 36.000, top-5 accuracy 88.000
# val part1: loss 1.520313
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 41 / 100
# train part1: batch 0/29, loss 1.679, top-1 accuracy 46.000, top-5 accuracy 88.000
# train part1: loss 1.586624
# val part1: batch 0/59, loss 1.873, top-1 accuracy 22.000, top-5 accuracy 82.000
# val part1: loss 1.575248
# Checkpoint saved
# part1 Epoch 42 / 100
# train part1: batch 0/29, loss 1.539, top-1 accuracy 50.000, top-5 accuracy 84.000
# train part1: loss 1.605438
# val part1: batch 0/59, loss 1.608, top-1 accuracy 44.000, top-5 accuracy 82.000
# val part1: loss 1.566487
# Checkpoint saved
# part1 Epoch 43 / 100
# train part1: batch 0/29, loss 1.521, top-1 accuracy 42.000, top-5 accuracy 90.000
# train part1: loss 1.594225
# val part1: batch 0/59, loss 1.995, top-1 accuracy 26.000, top-5 accuracy 80.000
# val part1: loss 1.559762
# Checkpoint saved
# part1 Epoch 44 / 100
# train part1: batch 0/29, loss 1.686, top-1 accuracy 44.000, top-5 accuracy 88.000
# train part1: loss 1.564704
# val part1: batch 0/59, loss 1.979, top-1 accuracy 28.000, top-5 accuracy 78.000
# val part1: loss 1.699789
# Checkpoint saved
# part1 Epoch 45 / 100
# train part1: batch 0/29, loss 1.639, top-1 accuracy 46.000, top-5 accuracy 86.000
# train part1: loss 1.596651
# val part1: batch 0/59, loss 1.606, top-1 accuracy 50.000, top-5 accuracy 84.000
# val part1: loss 1.565280
# Checkpoint saved
# part1 Epoch 46 / 100
# train part1: batch 0/29, loss 1.366, top-1 accuracy 60.000, top-5 accuracy 92.000
# train part1: loss 1.528920
# val part1: batch 0/59, loss 2.400, top-1 accuracy 12.000, top-5 accuracy 62.000
# val part1: loss 1.571233
# Checkpoint saved
# part1 Epoch 47 / 100
# train part1: batch 0/29, loss 1.656, top-1 accuracy 46.000, top-5 accuracy 84.000
# train part1: loss 1.535660
# val part1: batch 0/59, loss 1.761, top-1 accuracy 40.000, top-5 accuracy 86.000
# val part1: loss 1.564047
# Checkpoint saved
# part1 Epoch 48 / 100
# train part1: batch 0/29, loss 1.498, top-1 accuracy 54.000, top-5 accuracy 92.000
# train part1: loss 1.565598
# val part1: batch 0/59, loss 2.155, top-1 accuracy 18.000, top-5 accuracy 76.000
# val part1: loss 1.619319
# Checkpoint saved
# part1 Epoch 49 / 100
# train part1: batch 0/29, loss 1.516, top-1 accuracy 44.000, top-5 accuracy 86.000
# train part1: loss 1.659723
# val part1: batch 0/59, loss 2.048, top-1 accuracy 26.000, top-5 accuracy 78.000
# val part1: loss 1.824068
# Checkpoint saved
# part1 Epoch 50 / 100
# train part1: batch 0/29, loss 1.663, top-1 accuracy 40.000, top-5 accuracy 88.000
# train part1: loss 1.654659
# val part1: batch 0/59, loss 1.968, top-1 accuracy 28.000, top-5 accuracy 70.000
# val part1: loss 1.586686
# Checkpoint saved
# part1 Epoch 51 / 100
# train part1: batch 0/29, loss 1.593, top-1 accuracy 48.000, top-5 accuracy 84.000
# train part1: loss 1.578329
# val part1: batch 0/59, loss 2.008, top-1 accuracy 18.000, top-5 accuracy 76.000
# val part1: loss 1.610529
# Checkpoint saved
# part1 Epoch 52 / 100
# train part1: batch 0/29, loss 1.484, top-1 accuracy 50.000, top-5 accuracy 90.000
# train part1: loss 1.547567
# val part1: batch 0/59, loss 2.285, top-1 accuracy 10.000, top-5 accuracy 66.000
# val part1: loss 1.538403
# Checkpoint saved
# part1 Epoch 53 / 100
# train part1: batch 0/29, loss 1.429, top-1 accuracy 46.000, top-5 accuracy 96.000
# train part1: loss 1.555588
# val part1: batch 0/59, loss 1.959, top-1 accuracy 32.000, top-5 accuracy 84.000
# val part1: loss 1.532059
# Checkpoint saved
# part1 Epoch 54 / 100
# train part1: batch 0/29, loss 1.419, top-1 accuracy 56.000, top-5 accuracy 96.000
# train part1: loss 1.515001
# val part1: batch 0/59, loss 1.908, top-1 accuracy 32.000, top-5 accuracy 72.000
# val part1: loss 1.499888
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 55 / 100
# train part1: batch 0/29, loss 1.480, top-1 accuracy 48.000, top-5 accuracy 94.000
# train part1: loss 1.521491
# val part1: batch 0/59, loss 1.706, top-1 accuracy 42.000, top-5 accuracy 78.000
# val part1: loss 1.544588
# Checkpoint saved
# part1 Epoch 56 / 100
# train part1: batch 0/29, loss 1.583, top-1 accuracy 42.000, top-5 accuracy 82.000
# train part1: loss 1.519410
# val part1: batch 0/59, loss 1.710, top-1 accuracy 36.000, top-5 accuracy 86.000
# val part1: loss 1.566980
# Checkpoint saved
# part1 Epoch 57 / 100
# train part1: batch 0/29, loss 1.504, top-1 accuracy 52.000, top-5 accuracy 92.000
# train part1: loss 1.489370
# val part1: batch 0/59, loss 1.840, top-1 accuracy 32.000, top-5 accuracy 76.000
# val part1: loss 1.499264
# Checkpoint saved
# part1 Epoch 58 / 100
# train part1: batch 0/29, loss 1.414, top-1 accuracy 56.000, top-5 accuracy 88.000
# train part1: loss 1.533164
# val part1: batch 0/59, loss 1.763, top-1 accuracy 46.000, top-5 accuracy 74.000
# val part1: loss 1.552994
# Checkpoint saved
# part1 Epoch 59 / 100
# train part1: batch 0/29, loss 1.534, top-1 accuracy 50.000, top-5 accuracy 88.000
# train part1: loss 1.499076
# val part1: batch 0/59, loss 1.868, top-1 accuracy 30.000, top-5 accuracy 76.000
# val part1: loss 1.542867
# Checkpoint saved
# part1 Epoch 60 / 100
# train part1: batch 0/29, loss 1.370, top-1 accuracy 48.000, top-5 accuracy 96.000
# train part1: loss 1.438882
# val part1: batch 0/59, loss 1.841, top-1 accuracy 28.000, top-5 accuracy 84.000
# val part1: loss 1.485853
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 61 / 100
# train part1: batch 0/29, loss 1.319, top-1 accuracy 54.000, top-5 accuracy 94.000
# train part1: loss 1.377306
# val part1: batch 0/59, loss 1.899, top-1 accuracy 28.000, top-5 accuracy 82.000
# val part1: loss 1.472251
# Checkpoint saved
# part1 Epoch 62 / 100
# train part1: batch 0/29, loss 1.302, top-1 accuracy 62.000, top-5 accuracy 96.000
# train part1: loss 1.389919
# val part1: batch 0/59, loss 1.883, top-1 accuracy 26.000, top-5 accuracy 86.000
# val part1: loss 1.459938
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 63 / 100
# train part1: batch 0/29, loss 1.479, top-1 accuracy 46.000, top-5 accuracy 88.000
# train part1: loss 1.396963
# val part1: batch 0/59, loss 1.856, top-1 accuracy 26.000, top-5 accuracy 86.000
# val part1: loss 1.467602
# Checkpoint saved
# part1 Epoch 64 / 100
# train part1: batch 0/29, loss 1.578, top-1 accuracy 48.000, top-5 accuracy 88.000
# train part1: loss 1.414819
# val part1: batch 0/59, loss 1.839, top-1 accuracy 26.000, top-5 accuracy 86.000
# val part1: loss 1.463011
# Checkpoint saved
# part1 Epoch 65 / 100
# train part1: batch 0/29, loss 1.366, top-1 accuracy 54.000, top-5 accuracy 94.000
# train part1: loss 1.388122
# val part1: batch 0/59, loss 1.913, top-1 accuracy 26.000, top-5 accuracy 86.000
# val part1: loss 1.450939
# Checkpoint saved
# part1 Epoch 66 / 100
# train part1: batch 0/29, loss 1.420, top-1 accuracy 56.000, top-5 accuracy 92.000
# train part1: loss 1.381831
# val part1: batch 0/59, loss 1.886, top-1 accuracy 30.000, top-5 accuracy 86.000
# val part1: loss 1.454723
# Checkpoint saved
# part1 Epoch 67 / 100
# train part1: batch 0/29, loss 1.306, top-1 accuracy 56.000, top-5 accuracy 96.000
# train part1: loss 1.364269
# val part1: batch 0/59, loss 1.789, top-1 accuracy 30.000, top-5 accuracy 86.000
# val part1: loss 1.452631
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 68 / 100
# train part1: batch 0/29, loss 1.414, top-1 accuracy 52.000, top-5 accuracy 92.000
# train part1: loss 1.371998
# val part1: batch 0/59, loss 1.896, top-1 accuracy 30.000, top-5 accuracy 80.000
# val part1: loss 1.445945
# Checkpoint saved
# part1 Epoch 69 / 100
# train part1: batch 0/29, loss 1.391, top-1 accuracy 58.000, top-5 accuracy 90.000
# train part1: loss 1.345158
# val part1: batch 0/59, loss 1.898, top-1 accuracy 30.000, top-5 accuracy 86.000
# val part1: loss 1.447893
# Checkpoint saved
# part1 Epoch 70 / 100
# train part1: batch 0/29, loss 1.450, top-1 accuracy 50.000, top-5 accuracy 92.000
# train part1: loss 1.376422
# val part1: batch 0/59, loss 1.874, top-1 accuracy 30.000, top-5 accuracy 84.000
# val part1: loss 1.449058
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 71 / 100
# train part1: batch 0/29, loss 1.328, top-1 accuracy 56.000, top-5 accuracy 94.000
# train part1: loss 1.359181
# val part1: batch 0/59, loss 1.936, top-1 accuracy 28.000, top-5 accuracy 86.000
# val part1: loss 1.446393
# Checkpoint saved
# part1 Epoch 72 / 100
# train part1: batch 0/29, loss 1.482, top-1 accuracy 46.000, top-5 accuracy 94.000
# train part1: loss 1.379434
# val part1: batch 0/59, loss 1.926, top-1 accuracy 30.000, top-5 accuracy 84.000
# val part1: loss 1.443525
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 73 / 100
# train part1: batch 0/29, loss 1.199, top-1 accuracy 60.000, top-5 accuracy 94.000
# train part1: loss 1.350933
# val part1: batch 0/59, loss 1.938, top-1 accuracy 28.000, top-5 accuracy 86.000
# val part1: loss 1.446519
# Checkpoint saved
# part1 Epoch 74 / 100
# train part1: batch 0/29, loss 1.297, top-1 accuracy 62.000, top-5 accuracy 92.000
# train part1: loss 1.320141
# val part1: batch 0/59, loss 1.892, top-1 accuracy 28.000, top-5 accuracy 86.000
# val part1: loss 1.445254
# Checkpoint saved
# part1 Epoch 75 / 100
# train part1: batch 0/29, loss 1.296, top-1 accuracy 62.000, top-5 accuracy 94.000
# train part1: loss 1.361744
# val part1: batch 0/59, loss 1.875, top-1 accuracy 30.000, top-5 accuracy 86.000
# val part1: loss 1.447501
# Checkpoint saved
# part1 Epoch 76 / 100
# train part1: batch 0/29, loss 1.258, top-1 accuracy 50.000, top-5 accuracy 96.000
# train part1: loss 1.369930
# val part1: batch 0/59, loss 1.965, top-1 accuracy 30.000, top-5 accuracy 84.000
# val part1: loss 1.440468
# Checkpoint saved
# part1 Epoch 77 / 100
# train part1: batch 0/29, loss 1.068, top-1 accuracy 68.000, top-5 accuracy 94.000
# train part1: loss 1.318371
# val part1: batch 0/59, loss 1.907, top-1 accuracy 30.000, top-5 accuracy 78.000
# val part1: loss 1.439489
# Checkpoint saved
# part1 Epoch 78 / 100
# train part1: batch 0/29, loss 1.496, top-1 accuracy 44.000, top-5 accuracy 98.000
# train part1: loss 1.345452
# val part1: batch 0/59, loss 1.915, top-1 accuracy 28.000, top-5 accuracy 84.000
# val part1: loss 1.438225
# Checkpoint saved
# part1 Epoch 79 / 100
# train part1: batch 0/29, loss 1.110, top-1 accuracy 66.000, top-5 accuracy 92.000
# train part1: loss 1.346349
# val part1: batch 0/59, loss 1.956, top-1 accuracy 30.000, top-5 accuracy 84.000
# val part1: loss 1.436070
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 80 / 100
# train part1: batch 0/29, loss 1.126, top-1 accuracy 62.000, top-5 accuracy 94.000
# train part1: loss 1.323693
# val part1: batch 0/59, loss 1.943, top-1 accuracy 30.000, top-5 accuracy 86.000
# val part1: loss 1.440371
# Checkpoint saved
# part1 Epoch 81 / 100
# train part1: batch 0/29, loss 1.323, top-1 accuracy 54.000, top-5 accuracy 94.000
# train part1: loss 1.350657
# val part1: batch 0/59, loss 1.930, top-1 accuracy 30.000, top-5 accuracy 84.000
# val part1: loss 1.438830
# Checkpoint saved
# part1 Epoch 82 / 100
# train part1: batch 0/29, loss 1.612, top-1 accuracy 44.000, top-5 accuracy 90.000
# train part1: loss 1.349846
# val part1: batch 0/59, loss 1.875, top-1 accuracy 28.000, top-5 accuracy 82.000
# val part1: loss 1.444007
# Checkpoint saved
# part1 Epoch 83 / 100
# train part1: batch 0/29, loss 1.381, top-1 accuracy 52.000, top-5 accuracy 94.000
# train part1: loss 1.336427
# val part1: batch 0/59, loss 1.875, top-1 accuracy 30.000, top-5 accuracy 82.000
# val part1: loss 1.438850
# Checkpoint saved
# part1 Epoch 84 / 100
# train part1: batch 0/29, loss 1.359, top-1 accuracy 54.000, top-5 accuracy 96.000
# train part1: loss 1.312410
# val part1: batch 0/59, loss 1.904, top-1 accuracy 30.000, top-5 accuracy 84.000
# val part1: loss 1.441198
# Checkpoint saved
# part1 Epoch 85 / 100
# train part1: batch 0/29, loss 1.236, top-1 accuracy 54.000, top-5 accuracy 94.000
# train part1: loss 1.379279
# val part1: batch 0/59, loss 1.925, top-1 accuracy 26.000, top-5 accuracy 76.000
# val part1: loss 1.443243
# Checkpoint saved
# part1 Epoch 86 / 100
# train part1: batch 0/29, loss 1.453, top-1 accuracy 54.000, top-5 accuracy 86.000
# train part1: loss 1.357285
# val part1: batch 0/59, loss 1.902, top-1 accuracy 28.000, top-5 accuracy 84.000
# val part1: loss 1.440195
# Checkpoint saved
# part1 Epoch 87 / 100
# train part1: batch 0/29, loss 0.974, top-1 accuracy 72.000, top-5 accuracy 96.000
# train part1: loss 1.329840
# val part1: batch 0/59, loss 1.918, top-1 accuracy 28.000, top-5 accuracy 86.000
# val part1: loss 1.434695
# Checkpoint saved
# part1 Epoch 88 / 100
# train part1: batch 0/29, loss 1.481, top-1 accuracy 46.000, top-5 accuracy 94.000
# train part1: loss 1.362947
# val part1: batch 0/59, loss 1.748, top-1 accuracy 32.000, top-5 accuracy 90.000
# val part1: loss 1.443570
# Checkpoint saved
# part1 Epoch 89 / 100
# train part1: batch 0/29, loss 1.342, top-1 accuracy 50.000, top-5 accuracy 96.000
# train part1: loss 1.342074
# val part1: batch 0/59, loss 1.856, top-1 accuracy 30.000, top-5 accuracy 86.000
# val part1: loss 1.438799
# Checkpoint saved
# part1 Epoch 90 / 100
# train part1: batch 0/29, loss 1.456, top-1 accuracy 46.000, top-5 accuracy 90.000
# train part1: loss 1.357354
# val part1: batch 0/59, loss 1.861, top-1 accuracy 28.000, top-5 accuracy 84.000
# val part1: loss 1.440724
# Checkpoint saved
# part1 Epoch 91 / 100
# train part1: batch 0/29, loss 1.358, top-1 accuracy 50.000, top-5 accuracy 92.000
# train part1: loss 1.327874
# val part1: batch 0/59, loss 1.871, top-1 accuracy 28.000, top-5 accuracy 82.000
# val part1: loss 1.434580
# Checkpoint saved
# part1 Epoch 92 / 100
# train part1: batch 0/29, loss 1.361, top-1 accuracy 52.000, top-5 accuracy 94.000
# train part1: loss 1.340625
# val part1: batch 0/59, loss 1.824, top-1 accuracy 26.000, top-5 accuracy 82.000
# val part1: loss 1.448844
# Checkpoint saved
# part1 Epoch 93 / 100
# train part1: batch 0/29, loss 1.176, top-1 accuracy 56.000, top-5 accuracy 92.000
# train part1: loss 1.342021
# val part1: batch 0/59, loss 1.805, top-1 accuracy 30.000, top-5 accuracy 86.000
# val part1: loss 1.434405
# Checkpoint saved
# part1 Epoch 94 / 100
# train part1: batch 0/29, loss 1.327, top-1 accuracy 54.000, top-5 accuracy 94.000
# train part1: loss 1.333835
# val part1: batch 0/59, loss 1.887, top-1 accuracy 28.000, top-5 accuracy 82.000
# val part1: loss 1.442793
# Checkpoint saved
# part1 Epoch 95 / 100
# train part1: batch 0/29, loss 1.437, top-1 accuracy 56.000, top-5 accuracy 88.000
# train part1: loss 1.344795
# val part1: batch 0/59, loss 1.884, top-1 accuracy 30.000, top-5 accuracy 82.000
# val part1: loss 1.435155
# Checkpoint saved
# part1 Epoch 96 / 100
# train part1: batch 0/29, loss 1.184, top-1 accuracy 50.000, top-5 accuracy 94.000
# train part1: loss 1.320201
# val part1: batch 0/59, loss 1.846, top-1 accuracy 30.000, top-5 accuracy 84.000
# val part1: loss 1.441122
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 97 / 100
# train part1: batch 0/29, loss 1.394, top-1 accuracy 52.000, top-5 accuracy 92.000
# train part1: loss 1.325968
# val part1: batch 0/59, loss 1.896, top-1 accuracy 30.000, top-5 accuracy 82.000
# val part1: loss 1.440178
# Checkpoint saved
# part1 Epoch 98 / 100
# train part1: batch 0/29, loss 1.249, top-1 accuracy 64.000, top-5 accuracy 88.000
# train part1: loss 1.333497
# val part1: batch 0/59, loss 1.882, top-1 accuracy 30.000, top-5 accuracy 82.000
# val part1: loss 1.443207
# Checkpoint saved
# part1 Epoch 99 / 100
# train part1: batch 0/29, loss 0.915, top-1 accuracy 66.000, top-5 accuracy 100.000
# train part1: loss 1.326274
# val part1: batch 0/59, loss 1.906, top-1 accuracy 30.000, top-5 accuracy 80.000
# val part1: loss 1.445251
# Checkpoint saved
# Best top-1 Accuracy = 53.970
# Connection is already closed.
# Connection is already closed.
# Connection is already closed.
# Connection is already closed.
# Connection is already closed.
# Connection is already closed.

# %% [markdown]
# Make sure you get at least 50% accuracy in this section! If you tried different settings than the ones provided to get 50%, you should modify custom_part1_trainer in student code to return a dictionary with your changed settings.

# %% [markdown]
# ## Part 2. Fine-Tuning a Pre-Trained Network

# %%
# Fix random seeds so that results will be reproducible
set_seed(0, use_GPU)

# %% [markdown]
# Training a network from scratch takes a lof of time. Instead of training from scratch, we can take a pre-trained model and fine tune it for our purposes. This is the goal of Part 2--you will train a pre-trained network, and achieve at least 80% accuracy.

# %%
# training parameters
input_size = (224, 224)
RGB = True
base_lr = 1e-3
weight_decay = 5e-4
momentum = 0.9
backprop_depth = 3

# %%
# Create the training and testing datasets.
train_dataset, test_dataset = sc.create_datasets(data_path=data_path, input_size=input_size, rgb=RGB)
assert test_dataset.classes == train_dataset.classes
# Out:
# Computing pixel mean and stdev...
# Batch 0 / 30
# Batch 20 / 30
# Done, mean =
# [0.45611589 0.45611589 0.45611589]
# std =
# [0.24786406 0.24786406 0.24786406]
# Computing pixel mean and stdev...
# Batch 0 / 60
# Batch 20 / 60
# Batch 40 / 60
# Done, mean =
# [0.45549639 0.45549639 0.45549639]
# std =
# [0.24698076 0.24698076 0.24698076]

# %% [markdown]
# Following block loads a pretrained AlexNet.

# %%
# Create the network model.
model = alexnet(pretrained=True)
print(model)
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace)
#     (3): Dropout(p=0.5)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %% [markdown]
# Now, you modify create_part2_model from student code in order to fine-tune AlexNet. As you can see in the docs (https://github.com/pytorch/vision/blob/master/torchvision/models/alexnet.py) and in the model printout above, AlexNet has 2 parts: 'features', which constists of conv layers that extract feature maps from the image, and 'classifier' which consists of FC layers that classify the features. We want to replace the last Linear layer in model.classifier.

# %%
model = sc.create_part2_model(model, num_classes)
if use_GPU:
    model = model.cuda()
print(model)
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace)
#     (3): Dropout(p=0.5)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace)
#     (6): Linear(in_features=4096, out_features=15, bias=True)
#   )
# )

# %% [markdown]
# Next we will create the loss function and the optimizer. Just as with part 1, if you modify any of the setttings to hit the required accuracy, you must modify custom_part2_trainer function to return a dictionary containing your changes.

# %%
# Set up the trainer. You can modify custom_part2_trainer in
# student_copy.py if you want to try different learning settings.
custom_part2_trainer = sc.custom_part2_trainer(model)

if custom_part2_trainer is None:
    # Create the loss function
    # see http://pytorch.org/docs/0.3.0/nn.html#loss-functions for a list of available loss functions
    loss_function = nn.CrossEntropyLoss()

    # Since we do not want to optimize the whole network, we must extract a list of parameters of interest that will be
    # optimized by the optimizer.
    params_to_optimize = []

    # List of modules in the network
    mods = list(model.features.children()) + list(model.classifier.children())

    # Extract parameters from the last `backprop_depth` modules in the network and collect them in
    # the params_to_optimize list.
    for m in mods[::-1][:backprop_depth]:
        params_to_optimize.extend(list(m.parameters()))

    # Construct the optimizer    
    optimizer = optim.SGD(params=params_to_optimize, lr=base_lr, weight_decay=weight_decay, momentum=momentum)

    # Create a scheduler, currently a simple step scheduler, but you can get creative.
    # See http://pytorch.org/docs/0.3.0/optim.html#how-to-adjust-learning-rate for various LR schedulers
    # and how to use them
    lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
    
    params = {'n_epochs': 4, 'batch_size': 10, 'experiment': 'part2'} 
    
else:
    if 'loss_function' in custom_part2_trainer:
        loss_function = custom_part2_trainer['loss_function']
    if 'optimizer' in custom_part2_trainer:
        optimizer = custom_part2_trainer['optimizer']
    if 'lr_scheduler' in custom_part2_trainer:
        lr_scheduler = custom_part2_trainer['lr_scheduler']
    if 'params' in custom_part2_trainer:
        params = custom_part2_trainer['params']

# %% [markdown]
# We are ready to fine tune our network! Just like before, we will start a local server to see the training progress of our network. Open a new terminal and activate the environment for this project. Then run the following command: **python -m visdom.server**. This will start a local server. The terminal output should give out a link like: "http://localhost:8097". Open this link in your browser. After you run the following block, visit this link again, and you will be able to see graphs showing the progress of your training! If you do not see any graphs, select Part 2 on the top left bar where is says Environment (only select Part 2, do not check main or Part 1).

# %%
# Train the network!
trainer = Trainer(train_dataset, test_dataset, model, loss_function, optimizer, lr_scheduler, params)
best_prec1 = trainer.train_val()
print('Best top-1 Accuracy = {:4.3f}'.format(best_prec1))
# Out:
# ---------------------------------------
# Experiment: part2
# do_val: True
# n_epochs: 4
# val_freq: 1
# experiment: part2
# resume_optim: True
# shuffle: True
# batch_size: 10
# checkpoint_file: None
# print_freq: 100
# num_workers: 4
# ---------------------------------------
# part2 Epoch 0 / 4
# train part2: batch 0/149, loss 1.362, top-1 accuracy 60.000, top-5 accuracy 90.000
# train part2: batch 100/149, loss 0.927, top-1 accuracy 70.000, top-5 accuracy 100.000
# train part2: loss 0.767338
# val part2: batch 0/298, loss 0.790, top-1 accuracy 70.000, top-5 accuracy 100.000
# val part2: batch 100/298, loss 0.273, top-1 accuracy 80.000, top-5 accuracy 100.000
# val part2: batch 200/298, loss 0.224, top-1 accuracy 90.000, top-5 accuracy 100.000
# val part2: loss 0.575863
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part2 Epoch 1 / 4
# train part2: batch 0/149, loss 1.094, top-1 accuracy 50.000, top-5 accuracy 100.000
# train part2: batch 100/149, loss 1.136, top-1 accuracy 60.000, top-5 accuracy 90.000
# train part2: loss 0.700281
# val part2: batch 0/298, loss 1.254, top-1 accuracy 40.000, top-5 accuracy 100.000
# val part2: batch 100/298, loss 0.193, top-1 accuracy 90.000, top-5 accuracy 100.000
# val part2: batch 200/298, loss 0.282, top-1 accuracy 80.000, top-5 accuracy 100.000
# val part2: loss 0.639437
# Checkpoint saved
# part2 Epoch 2 / 4
# train part2: batch 0/149, loss 0.224, top-1 accuracy 90.000, top-5 accuracy 100.000
# train part2: batch 100/149, loss 0.830, top-1 accuracy 60.000, top-5 accuracy 100.000
# train part2: loss 0.645755
# val part2: batch 0/298, loss 0.840, top-1 accuracy 80.000, top-5 accuracy 100.000
# val part2: batch 100/298, loss 0.167, top-1 accuracy 90.000, top-5 accuracy 100.000
# val part2: batch 200/298, loss 0.332, top-1 accuracy 80.000, top-5 accuracy 100.000
# val part2: loss 0.607906
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part2 Epoch 3 / 4
# train part2: batch 0/149, loss 0.387, top-1 accuracy 80.000, top-5 accuracy 100.000
# train part2: batch 100/149, loss 0.248, top-1 accuracy 100.000, top-5 accuracy 100.000
# train part2: loss 0.627858
# val part2: batch 0/298, loss 1.043, top-1 accuracy 50.000, top-5 accuracy 100.000
# val part2: batch 100/298, loss 0.399, top-1 accuracy 80.000, top-5 accuracy 100.000
# val part2: batch 200/298, loss 0.185, top-1 accuracy 90.000, top-5 accuracy 100.000
# val part2: loss 0.647809
# Checkpoint saved
# Best top-1 Accuracy = 80.335

# %% [markdown]
# Expect this code to take around 10 minutes on CPU or 30 seconds on GPU. You should hit 80% accuracy.
